# %%
import pandas as pd

# %% [markdown]
# # Lectura del archivo VENTAS_TOTALES.CSV

# %%
pd.read_csv('VENTAS_TOTALES.csv',sep=';')
# Out:
#         SEGMENTO   TIPOVENTA  PRODUCTO  CANTIDADUNIDADES  PRECIOVENTA  \
# 0       GOBIERNO      OnLine         1             330.0          125
# 1            NaN     Mailing         1            1834.0           20
# 2            NaN  Sucursales         1            2416.0          125
# 3        EMPRESA      OnSite         1               NaN           20
# 4       GOBIERNO      OnLine         1            1023.0          125
# ..           ...         ...       ...               ...          ...
# 696  Exportacion      OnLine         6             853.0          300
# 697     Personas     Mailing         6            2157.0           15
# 698  Exportacion      OnLine         6            1372.0          300
# 699     Personas      OnSite         6             711.0           15
# 700     Personas      OnLine         6            2072.0           15
#
#      IMPORTEVENTAS FECHAVENTA  DIAVENTA  MESVENTA  ANIOVENTA NOMBREPRODUCTO
# ...

# %%
#Creo variable df_ventas_totales

# %%
df_ventas_totales=pd.read_csv('VENTAS_TOTALES.csv',sep=';')

# %%
df_ventas_totales
# Out:
#         SEGMENTO   TIPOVENTA  PRODUCTO  CANTIDADUNIDADES  PRECIOVENTA  \
# 0       gobierno      online         1             330.0          125
# 4       gobierno      online         1            1023.0          125
# 5    exportacion     mailing         1             494.0          300
# 6        empresa  sucursales         1            2851.0            7
# 9    exportacion      onsite         1             214.0          300
# ..           ...         ...       ...               ...          ...
# 696  exportacion      online         6             853.0          300
# 697     personas     mailing         6            2157.0           15
# 698  exportacion      online         6            1372.0          300
# 699     personas      onsite         6             711.0           15
# 700     personas      online         6            2072.0           15
#
#      IMPORTEVENTAS  DIAVENTA  MESVENTA  ANIOVENTA NOMBREPRODUCTO
# ...

# %%
# Qué tipo de datos tengo

# %%
df_ventas_totales.dtypes
# Out:
# SEGMENTO             object
# TIPOVENTA            object
# PRODUCTO              int64
# CANTIDADUNIDADES    float64
# PRECIOVENTA           int64
# IMPORTEVENTAS         int64
# FECHAVENTA           object
# DIAVENTA              int64
# MESVENTA              int64
# ANIOVENTA             int64
# NOMBREPRODUCTO       object
# dtype: object

# %%
#Normalizo con dtos string poniendolos en minúscula
df_ventas_totales.SEGMENTO=df_ventas_totales.SEGMENTO.str.lower()
df_ventas_totales.NOMBREPRODUCTO=df_ventas_totales.NOMBREPRODUCTO.str.lower()
df_ventas_totales.TIPOVENTA=df_ventas_totales.TIPOVENTA.str.lower()

# %%
df_ventas_totales
# Out:
#         SEGMENTO   TIPOVENTA  PRODUCTO  CANTIDADUNIDADES  PRECIOVENTA  \
# 0       gobierno      online         1             330.0          125
# 1            NaN     mailing         1            1834.0           20
# 2            NaN  sucursales         1            2416.0          125
# 3        empresa      onsite         1               NaN           20
# 4       gobierno      online         1            1023.0          125
# ..           ...         ...       ...               ...          ...
# 696  exportacion      online         6             853.0          300
# 697     personas     mailing         6            2157.0           15
# 698  exportacion      online         6            1372.0          300
# 699     personas      onsite         6             711.0           15
# 700     personas      online         6            2072.0           15
#
#      IMPORTEVENTAS FECHAVENTA  DIAVENTA  MESVENTA  ANIOVENTA NOMBREPRODUCTO
# ...

# %%
# Borro los registros NAN

# %%
df_ventas_totales=df_ventas_totales.dropna()

# %%
df_ventas_totales
# Out:
#         SEGMENTO   TIPOVENTA  PRODUCTO  CANTIDADUNIDADES  PRECIOVENTA  \
# 0       gobierno      online         1             330.0          125
# 4       gobierno      online         1            1023.0          125
# 5    exportacion     mailing         1             494.0          300
# 6        empresa  sucursales         1            2851.0            7
# 9    exportacion      onsite         1             214.0          300
# ..           ...         ...       ...               ...          ...
# 696  exportacion      online         6             853.0          300
# 697     personas     mailing         6            2157.0           15
# 698  exportacion      online         6            1372.0          300
# 699     personas      onsite         6             711.0           15
# 700     personas      online         6            2072.0           15
#
#      IMPORTEVENTAS  DIAVENTA  MESVENTA  ANIOVENTA NOMBREPRODUCTO
# ...

# %%
# Recalculo campo Importe Ventas

# %%
df_ventas_totales.IMPORTEVENTAS=df_ventas_totales['CANTIDADUNIDADES'].mul(df_ventas_totales['PRECIOVENTA'])
# Out:
# C:\Users\pac\anaconda3\lib\site-packages\pandas\core\generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df_ventas_totales
# Out:
#         SEGMENTO   TIPOVENTA  PRODUCTO  CANTIDADUNIDADES  PRECIOVENTA  \
# 0       gobierno      online         1             330.0          125
# 4       gobierno      online         1            1023.0          125
# 5    exportacion     mailing         1             494.0          300
# 6        empresa  sucursales         1            2851.0            7
# 9    exportacion      onsite         1             214.0          300
# ..           ...         ...       ...               ...          ...
# 696  exportacion      online         6             853.0          300
# 697     personas     mailing         6            2157.0           15
# 698  exportacion      online         6            1372.0          300
# 699     personas      onsite         6             711.0           15
# 700     personas      online         6            2072.0           15
#
#      IMPORTEVENTAS  DIAVENTA  MESVENTA  ANIOVENTA NOMBREPRODUCTO
# ...

# %%
# Borro la columna Fecha Ventas.

# %%
df_ventas_totales=df_ventas_totales.drop(columns='FECHAVENTA')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-55b0ee657641> in <module>
# ----> 1 df_ventas_totales=df_ventas_totales.drop(columns='FECHAVENTA')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
df_ventas_totales
# Out:
#         SEGMENTO   TIPOVENTA  PRODUCTO  CANTIDADUNIDADES  PRECIOVENTA  \
# 0       gobierno      online         1             330.0          125
# 4       gobierno      online         1            1023.0          125
# 5    exportacion     mailing         1             494.0          300
# 6        empresa  sucursales         1            2851.0            7
# 9    exportacion      onsite         1             214.0          300
# ..           ...         ...       ...               ...          ...
# 696  exportacion      online         6             853.0          300
# 697     personas     mailing         6            2157.0           15
# 698  exportacion      online         6            1372.0          300
# 699     personas      onsite         6             711.0           15
# 700     personas      online         6            2072.0           15
#
#      IMPORTEVENTAS  DIAVENTA  MESVENTA  ANIOVENTA NOMBREPRODUCTO
# ...

# %%
#genero dataframe prductos con 3 columnas y renombro columnas
df_productos=df_ventas_totales[['PRODUCTO','NOMBREPRODUCTO','IMPORTEVENTAS']]
df_productos.rename(columns={'NOMBREPRODUCTO':'NOMBRE','IMPORTEVENTAS':'TOTAL DE VENTAS'},inplace=True)
# Out:
# C:\Users\pac\anaconda3\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df_productos
# Out:
#      PRODUCTO     NOMBRE  TOTAL DE VENTAS
# 0           1       mesa          41250.0
# 4           1       mesa         127875.0
# 5           1       mesa         148200.0
# 6           1       mesa          19957.0
# 9           1       mesa          64200.0
# ..        ...        ...              ...
# 696         6  lavarropa         255900.0
# 697         6  lavarropa          32355.0
# 698         6  lavarropa         411600.0
# 699         6  lavarropa          10665.0
# 700         6  lavarropa          31080.0
#
# [690 rows x 3 columns]

# %%
#agrupo las tres columnas por el producto y su nombre y luego calculo la suma total de cada producto. 
df_productos=df_productos.groupby(['PRODUCTO','NOMBRE']).sum()

# %%
df_productos
# Out:
#                     TOTAL DE VENTAS
# PRODUCTO NOMBRE
# 1        mesa            14548599.0
# 2        tv              15993587.0
# 3        sillon          35421028.0
# 4        silla           19826601.0
# 5        cocina          22117969.0
# 6        lavarropa       19037130.0

# %%
#genero del archivo.csv productos
df_productos.to_csv('PRODUCTOS_piaacuna.csv',sep=';')

# %%
#Genero el archivo VENTAS_ con los campos.
#SEGMENTO
#TIPO VENTA
#PRODUCTO
#CANTIDAD UNIDADES
#PRECIO VENTA
#IMPORTE VENTAS
#DIA VENTA
#MES VENTA
#ANIO VENTA

# %%
df_ventas_totales
# Out:
#         SEGMENTO   TIPOVENTA  PRODUCTO  CANTIDADUNIDADES  PRECIOVENTA  \
# 0       gobierno      online         1             330.0          125
# 4       gobierno      online         1            1023.0          125
# 5    exportacion     mailing         1             494.0          300
# 6        empresa  sucursales         1            2851.0            7
# 9    exportacion      onsite         1             214.0          300
# ..           ...         ...       ...               ...          ...
# 696  exportacion      online         6             853.0          300
# 697     personas     mailing         6            2157.0           15
# 698  exportacion      online         6            1372.0          300
# 699     personas      onsite         6             711.0           15
# 700     personas      online         6            2072.0           15
#
#      IMPORTEVENTAS  DIAVENTA  MESVENTA  ANIOVENTA NOMBREPRODUCTO
# ...

# %%
#genero mi dataframe de ventas para luego generar el archivo csv
df_ventas=df_ventas_totales[['SEGMENTO','TIPOVENTA','PRODUCTO','CANTIDADUNIDADES','PRECIOVENTA','IMPORTEVENTAS','DIAVENTA','MESVENTA','ANIOVENTA']]

# %%
df_ventas
# Out:
#         SEGMENTO   TIPOVENTA  PRODUCTO  CANTIDADUNIDADES  PRECIOVENTA  \
# 0       gobierno      online         1             330.0          125
# 4       gobierno      online         1            1023.0          125
# 5    exportacion     mailing         1             494.0          300
# 6        empresa  sucursales         1            2851.0            7
# 9    exportacion      onsite         1             214.0          300
# ..           ...         ...       ...               ...          ...
# 696  exportacion      online         6             853.0          300
# 697     personas     mailing         6            2157.0           15
# 698  exportacion      online         6            1372.0          300
# 699     personas      onsite         6             711.0           15
# 700     personas      online         6            2072.0           15
#
#      IMPORTEVENTAS  DIAVENTA  MESVENTA  ANIOVENTA
# 0          41250.0         1         9       2013
# ...

# %%
#generación del archivo.csv ventas
df_ventas.to_csv('VENTAS_piaacuna.csv',sep=';')
